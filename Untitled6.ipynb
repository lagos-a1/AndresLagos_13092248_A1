# %% [markdown]
# <a href="https://colab.research.google.com/github/lagos-a1/AndresLagos_13092248_A1/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install python-cartopy python3-cartopy
import cartopy
# Out:
# Selecting previously unselected package python-pkg-resources.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../0-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-pyshp.
# Preparing to unpack .../1-python-pyshp_1.2.12+ds-1_all.deb ...
# Unpacking python-pyshp (1.2.12+ds-1) ...
# Selecting previously unselected package python-shapely.
# Preparing to unpack .../2-python-shapely_1.6.4-1_amd64.deb ...
# Unpacking python-shapely (1.6.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-cartopy:amd64.
# Preparing to unpack .../4-python-cartopy_0.14.2+dfsg1-2build3_amd64.deb ...
# Unpacking python-cartopy:amd64 (0.14.2+dfsg1-2build3) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../5-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-pyshp.
# Preparing to unpack .../6-python3-pyshp_1.2.12+ds-1_all.deb ...
# Unpacking python3-pyshp (1.2.12+ds-1) ...
# Selecting previously unselected package python3-shapely.
# Preparing to unpack .../7-python3-shapely_1.6.4-1_amd64.deb ...
# Unpacking python3-shapely (1.6.4-1) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../8-python3-six_1.11.0-2_all.deb ...
# Unpacking python3-six (1.11.0-2) ...
# Selecting previously unselected package python3-cartopy:amd64.
# Preparing to unpack .../9-python3-cartopy_0.14.2+dfsg1-2build3_amd64.deb ...
# Unpacking python3-cartopy:amd64 (0.14.2+dfsg1-2build3) ...
# Setting up python-shapely (1.6.4-1) ...
# Setting up python-pyshp (1.2.12+ds-1) ...
# Setting up python3-six (1.11.0-2) ...
# Setting up python3-shapely (1.6.4-1) ...
# Setting up python3-pyshp (1.2.12+ds-1) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python3-cartopy:amd64 (0.14.2+dfsg1-2build3) ...
# Setting up python-cartopy:amd64 (0.14.2+dfsg1-2build3) ...

# %%
import math
import json
import numpy as np
import pandas as pd
import networkx as nx
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline

# %%
from google.colab import drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4fe4b19-cf22-40aa-a2a2-d6cffa83a39f" name="files[]" multiple disabled />
#      <output id="result-d4fe4b19-cf22-40aa-a2a2-d6cffa83a39f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data.csv to Data.csv

# %%
import io
flights = pd.read_csv(io.BytesIO(uploaded['Data.csv']))
# Dataset is now stored in a Pandas Dataframe
flights
# Out:
#    AirSpace class      From_City  ... Aircraft Model  Engine Model
# 0               B         Sydney  ...       A330-203     CF6-80E142
# 1               A         Sydney  ...       A330-202     CF6-80E142
# 2               B         Sydney  ...       B737-3B7      CFM56-3B1
# 3               B       Canberra  ...       B732-476       CFM-56-3
# 4               A         Sydney  ...       A320-232       V2527-5A
# 5               A      Newcastle  ...       A320-232       V2527-5A
# 6               B         Sydney  ...       A320-232       V2527-5A
# 7               B     Broke Hill  ...       A320-232       V2527-5A
# 8               C       Melburne  ...       A330-243        772B-60
# 9               B       Melburne  ...       A320-232       V2527-5A
# 10              B       Canberra  ...       A320-232       V2527-5A
# 11              A       Melburne  ...       B737-3B7      CFM56-3B1
# 12              A       Melburne  ...       A320-232       V2527-5A
# 13              A       Melburne  ...       B717-200        Unknown
# 14              A        Bendigo  ...       B717-200        Unknown
# 15              A       Melburne  ...       B737-3B7      CFM56-3B1
# 16              C       Adelaide  ...       B737-3B7      CFM56-3B1
# 17              C       Adelaide  ...       A320-232       V2527-5A
# 18              C     Broke Hill  ...       A320-232       V2527-5A
# 19              D       Adelaide  ...       A330-203     CF6-80E142
# 20              D       Adelaide  ...       A330-203     CF6-80E142
# 21              D         Darwin  ...       A330-203     CF6-80E142
# 22              E         Darwin  ...       B737-476       CFM-56-3
# 23              E  Alice Springs  ...       B737-476       CFM-56-3
# 24              D          Perth  ...       A330-203     CF6-80E142
# 25              C          Perth  ...       A320-232       V2527-5A
# 26              C          Perth  ...       A320-232       V2527-5A
# 27              C          Perth  ...       A320-232       V2527-5A
# 28              B         Albany  ...       A320-232       V2527-5A
# 29              C     Kalgoorlie  ...       A320-232       V2527-5A
# 30              B         Broome  ...       B737-476       CFM-56-3
# 31              B     Launceston  ...       B737-476       CFM-56-3
# 32              B     Launceston  ...       A320-232       V2527-5A
# 33              A         Hobart  ...       B737-3B7      CFM56-3B1
# 34              A         Hobart  ...       A320-232       V2527-5A
# 35              B       Brisbane  ...       A330-203     CF6-80E142
# 36              A       Brisbane  ...       B737-3B7      CFM56-3B1
# 37              A       Brisbane  ...       B737-3B7      CFM56-3B1
# 38              A       Brisbane  ...       A330-203     CF6-80E142
# 39              B       Brisbane  ...       A330-203     CF6-80E142
# 40              A      Mount Isa  ...       A330-202     CF6-80E142
# 41              B    Rockhampton  ...       A330-202     CF6-80E142
# 42              A         Cairns  ...       A330-203     CF6-80E142
# 43              A         Darwin  ...       A330-203     CF6-80E142
# 44              B      Mount Isa  ...       B737-3B7      CFM56-3B1
# 45              B         Darwin  ...       B737-3B7      CFM56-3B1
# 46              B       Adelaide  ...       B717-200        Unknown
# 47              C   Port Augusta  ...       B717-200        Unknown
#
# [48 rows x 6 columns]

# %%
names = ('id,name,city,country,iata,icao,lat,lon,'
         'alt,timezone,dst,tz,type,source').split(',')

airports = pd.read_csv(
    'https://github.com/ipython-books/'
    'cookbook-2nd-data/blob/master/'
    'airports.dat?raw=true',
    header=None,
    names=names,
    index_col=4,
    na_values='\\N')
airports_Aus = airports[airports['country'] ==
                       'Australia']
airports_Aus
# Out:
#          id                                 name  ...     type       source
# iata                                              ...
# NaN    3317         Brisbane Archerfield Airport  ...  airport  OurAirports
# ABM    3318           Northern Peninsula Airport  ...  airport  OurAirports
# ASP    3319                Alice Springs Airport  ...  airport  OurAirports
# BNE    3320       Brisbane International Airport  ...  airport  OurAirports
# OOL    3321                   Gold Coast Airport  ...  airport  OurAirports
# CNS    3322         Cairns International Airport  ...  airport  OurAirports
# CTL    3323                  Charleville Airport  ...  airport  OurAirports
# ISA    3324                    Mount Isa Airport  ...  airport  OurAirports
# MCY    3325               Sunshine Coast Airport  ...  airport  OurAirports
# MKY    3326                       Mackay Airport  ...  airport  OurAirports
# PPP    3328  Proserpine Whitsunday Coast Airport  ...  airport  OurAirports
# ROK    3329                  Rockhampton Airport  ...  airport  OurAirports
# TSV    3330                   Townsville Airport  ...  airport  OurAirports
# WEI    3331                        Weipa Airport  ...  airport  OurAirports
# AVV    3332                       Avalon Airport  ...  airport  OurAirports
# ABX    3333                       Albury Airport  ...  airport  OurAirports
# MEB    3334           Melbourne Essendon Airport  ...  airport  OurAirports
# NaN    3335                  RAAF Base East Sale  ...  airport  OurAirports
# HBA    3336         Hobart International Airport  ...  airport  OurAirports
# LST    3337                   Launceston Airport  ...  airport  OurAirports
# MBW    3338          Melbourne Moorabbin Airport  ...  airport  OurAirports
# MEL    3339      Melbourne International Airport  ...  airport  OurAirports
# NaN    3340       RAAF Williams, Point Cook Base  ...  airport  OurAirports
# ADL    3341       Adelaide International Airport  ...  airport  OurAirports
# NaN    3343                  RAAF Base Edinburgh  ...  airport  OurAirports
# JAD    3344               Perth Jandakot Airport  ...  airport  OurAirports
# KTA    3345                     Karratha Airport  ...  airport  OurAirports
# KGI    3346           Kalgoorlie Boulder Airport  ...  airport  OurAirports
# KNX    3347                    Kununurra Airport  ...  airport  OurAirports
# LEA    3348                    Learmonth Airport  ...  airport  OurAirports
# ...     ...                                  ...  ...      ...          ...
# CWW   12017                       Corowa Airport  ...  airport  OurAirports
# CYG   12018                     Corryong Airport  ...  airport  OurAirports
# CMD   12019                  Cootamundra Airport  ...  airport  OurAirports
# DRN   12020                  Dirranbandi Airport  ...  airport  OurAirports
# DNQ   12021                   Deniliquin Airport  ...  airport  OurAirports
# DYA   12022                       Dysart Airport  ...  airport  OurAirports
# ECH   12023                       Echuca Airport  ...  airport  OurAirports
# FRB   12024                       Forbes Airport  ...  airport  OurAirports
# GUH   12025                     Gunnedah Airport  ...  airport  OurAirports
# HXX   12026                          Hay Airport  ...  airport  OurAirports
# HTU   12027                     Hopetoun Airport  ...  airport  OurAirports
# KRA   12028                       Kerang Airport  ...  airport  OurAirports
# KPS   12029                      Kempsey Airport  ...  airport  OurAirports
# KGY   12030                     Kingaroy Airport  ...  airport  OurAirports
# TGN   12031               Latrobe Valley Airport  ...  airport  OurAirports
# MRG   12032                      Mareeba Airport  ...  airport  OurAirports
# RPM   12033                      Ngukurr Airport  ...  airport  OurAirports
# QRM   12034                    Narromine Airport  ...  airport  OurAirports
# PPI   12035                   Port Pirie Airport  ...  airport  OurAirports
# SIO   12036                     Smithton Airport  ...  airport  OurAirports
# SNB   12037                    Snake Bay Airport  ...  airport  OurAirports
# SWC   12038                      Stawell Airport  ...  airport  OurAirports
# TYB   12039                   Tibooburra Airport  ...  airport  OurAirports
# TUM   12040                        Tumut Airport  ...  airport  OurAirports
# WGT   12041                   Wangaratta Airport  ...  airport  OurAirports
# WKB   12042                Warracknabeal Airport  ...  airport  OurAirports
# QRR   12043                       Warren Airport  ...  airport  OurAirports
# SXE   12044                    West Sale Airport  ...  airport  OurAirports
# WWY   12045                 West Wyalong Airport  ...  airport  OurAirports
# NGA   12046                        Young Airport  ...  airport  OurAirports
#
# [296 rows x 13 columns]

# %% [markdown]
# We construct the list of edges representing our graph, where nodes are airports, and two airports are connected if there exists a route between them (flight network):

# %%
print(type(airports_Aus['lon'][0]))
# Out:
# <class 'numpy.float64'>

# %%
conection = flights [['From_City', 'To_City']].values
conection
# Out:
# array([['Sydney', 'Melburne'],
#        ['Sydney', 'Brisbane'],
#        ['Sydney', 'Canberra'],
#        ['Canberra', 'Sydney'],
#        ['Sydney', 'Newcastle'],
#        ['Newcastle', 'Sydney'],
#        ['Sydney', 'Broke Hill'],
#        ['Broke Hill', 'Sydney'],
#        ['Melburne', 'Sydney'],
#        ['Melburne', 'Canberra'],
#        ['Canberra', 'Melburne'],
#        ['Melburne', 'Adelaide'],
#        ['Melburne', 'Hobart'],
#        ['Melburne', 'Bendigo'],
#        ['Bendigo', 'Melburne'],
#        ['Melburne', 'Launceston'],
#        ['Adelaide', 'Melburne'],
#        ['Adelaide', 'Broke Hill'],
#        ['Broke Hill', 'Adelaide'],
#        ['Adelaide', 'Perth'],
#        ['Adelaide', 'Darwin'],
#        ['Darwin', 'Adelaide'],
#        ['Darwin', 'Alice Springs'],
#        ['Alice Springs', 'Darwin'],
#        ['Perth', 'Adelaide'],
#        ['Perth', 'Albany'],
#        ['Perth', 'Kalgoorlie'],
#        ['Perth', 'Broome'],
#        ['Albany', 'Perth'],
#        ['Kalgoorlie', 'Perth'],
#        ['Broome', 'Perth'],
#        ['Launceston', 'Melburne'],
#        ['Launceston', 'Hobart'],
#        ['Hobart', 'Melburne'],
#        ['Hobart', 'Launceston'],
#        ['Brisbane', 'Sydney'],
#        ['Brisbane', 'Mount Isa'],
#        ['Brisbane', 'Rockhampton'],
#        ['Brisbane', 'Cairns'],
#        ['Brisbane', 'Darwin'],
#        ['Mount Isa', 'Brisbane'],
#        ['Rockhampton', 'Brisbane'],
#        ['Cairns', 'Brisbane'],
#        ['Darwin', 'Brisbane'],
#        ['Mount Isa', 'Darwin'],
#        ['Darwin', 'Mount Isa'],
#        ['Adelaide', 'Port Augusta'],
#        ['Port Augusta', 'Adelaide']], dtype=object)

# %% [markdown]
# Let's create the networkX graph from the conection array

# %%
l = nx.from_edgelist(conection)

# %%
len(l.nodes()), len(l.edges())
# Out:
# (20, 24)

# %% [markdown]
# Exist 21 Airports in Australia and 25 routes

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_networkx(l, ax=ax, node_size=8,
                 font_size=8, alpha=.8,
                 width=.8)
ax.set_axis_off()

# %%
sg = next(nx.connected_component_subgraphs(l))

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
nx.draw_networkx(sg, ax=ax, with_labels=False,
                 node_size=5, width=.5)
ax.set_axis_off()

# %%
pos = {airport: (v['lon'], v['lat'])
       for airport, v in
       airports_Aus.to_dict('index').items()}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-416d575f816f> in <module>()
#       1 pos = {airport: (v['lon'], v['lat'])
#       2        for airport, v in
# ----> 3        airports_Aus.to_dict('index').items()}
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in to_dict(self, orient, into)
#    1314             if not self.index.is_unique:
#    1315                 raise ValueError(
# -> 1316                     "DataFrame index must be unique for orient='index'."
#    1317                 )
#    1318             return into_c((t[0], dict(zip(self.columns, t[1:])))
#
# ValueError: DataFrame index must be unique for orient='index'.

# %%
# Map projection
crs = ccrs.PlateCarree()
fig, ax = plt.subplots(
    1, 1, figsize=(12, 8),
    subplot_kw=dict(projection=crs))
ax.coastlines()
# Extent of continental US.
ax.set_extent([-108, -620, 40, 250])
nx.draw_networkx(sg, ax=ax,
                 font_size=16,
                 alpha=.5,
                 width=.075,
                 node_size=sizes,
                 labels=labels,
                 pos=pos,
                 node_color=altitude,
                 cmap=plt.cm.autumn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-42c9ad6294ec> in <module>()
#      11                  width=.075,
#      12                  node_size=sizes,
# ---> 13                  labels=labels,
#      14                  pos=pos,
#      15                  node_color=altitude,
#
# NameError: name 'labels' is not defined
